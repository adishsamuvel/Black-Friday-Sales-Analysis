# %%
import pandas as pd

# %%
df=pd.read_csv("BlackFriday.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df=pd.read_csv("BlackFriday.csv")
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
print("Overview of the Dataset")
df
# Out:
# Overview of the Dataset
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %% [markdown]
# #### Product Category 2 and 3 have more no of null values

# %%
df['Product_Category_2']
# Out:
# 0          NaN
# 1          6.0
# 2          NaN
# 3         14.0
# 4          NaN
#           ...
# 537572     2.0
# 537573    15.0
# 537574    15.0
# 537575     NaN
# 537576     8.0
# Name: Product_Category_2, Length: 537577, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %% [markdown]
# #### Delete the column having product category 2 and 3 as it has more number of null values

# %%
del df['Product_Category_2']
del df['Product_Category_3']

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Purchase                      0
# dtype: int64

# %%
for i in df.columns:
    print(i,":",df[i].nunique())
# Out:
# User_ID : 5891
# Product_ID : 3623
# Gender : 2
# Age : 7
# Occupation : 21
# City_Category : 3
# Stay_In_Current_City_Years : 5
# Marital_Status : 2
# Product_Category_1 : 18
# Purchase : 17959

# %%
df.describe()
# Out:
#             User_ID    Occupation  Marital_Status  Product_Category_1  \
# count  5.375770e+05  537577.00000   537577.000000       537577.000000
# mean   1.002992e+06       8.08271        0.408797            5.295546
# std    1.714393e+03       6.52412        0.491612            3.750701
# min    1.000001e+06       0.00000        0.000000            1.000000
# 25%    1.001495e+06       2.00000        0.000000            1.000000
# 50%    1.003031e+06       7.00000        0.000000            5.000000
# 75%    1.004417e+06      14.00000        1.000000            8.000000
# max    1.006040e+06      20.00000        1.000000           18.000000
#
#             Purchase
# count  537577.000000
# mean     9333.859853
# std      4981.022133
# min       185.000000
# 25%      5866.000000
# 50%      8062.000000
# 75%     12073.000000
# max     23961.000000

# %%
df1=df[df['Marital_Status']==1]
df2=df[df['Marital_Status']==0]

# %%
df1['Purchase'].sum()
# Out:
# 2051378878

# %%
#Unmarried people total Purchase:2966289500
#Married People total Purchase:2051378878

# %%
df1['Age'].unique()
# Out:
# array(['46-50', '26-35', '36-45', '18-25', '51-55', '55+'], dtype=object)

# %%
df1.head()
# Out:
#     User_ID Product_ID Gender    Age  Occupation City_Category  \
# 6   1000004  P00184942      M  46-50           7             B
# 7   1000004  P00346142      M  46-50           7             B
# 8   1000004   P0097242      M  46-50           7             B
# 9   1000005  P00274942      M  26-35          20             A
# 10  1000005  P00251242      M  26-35          20             A
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 6                           2               1                   1     19215
# 7                           2               1                   1     15854
# 8                           2               1                   1     15686
# 9                           1               1                   8      7871
# 10                          1               1                   5      5254

# %%
df2.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
print("Married People")
df1.describe()
# Out:
# Married People
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  2.197600e+05  219760.000000        219760.0       219760.000000
# mean   1.003030e+06       8.276429             1.0            5.388219
# std    1.752313e+03       6.688286             0.0            3.785414
# min    1.000004e+06       0.000000             1.0            1.000000
# 25%    1.001470e+06       2.000000             1.0            1.000000
# 50%    1.003054e+06       7.000000             1.0            5.000000
# 75%    1.004562e+06      14.000000             1.0            8.000000
# max    1.006039e+06      20.000000             1.0           18.000000
#
#             Purchase
# count  219760.000000
# mean     9334.632681
# std      4974.906972
# min       186.000000
# 25%      5886.000000
# 50%      8066.000000
# 75%     12065.000000
# max     23961.000000

# %%
print("Unmarried People")
df2.describe()
# Out:
# Unmarried People
#             User_ID    Occupation  Marital_Status  Product_Category_1  \
# count  3.178170e+05  317817.00000        317817.0       317817.000000
# mean   1.002965e+06       7.94876             0.0            5.231467
# std    1.687159e+03       6.40473             0.0            3.725167
# min    1.000001e+06       0.00000             0.0            1.000000
# 25%    1.001501e+06       3.00000             0.0            1.000000
# 50%    1.003020e+06       7.00000             0.0            5.000000
# 75%    1.004338e+06      14.00000             0.0            8.000000
# max    1.006040e+06      20.00000             0.0           18.000000
#
#             Purchase
# count  317817.000000
# mean     9333.325467
# std      4985.253932
# min       185.000000
# 25%      5850.000000
# 50%      8059.000000
# 75%     12080.000000
# max     23961.000000

# %%
df2['Product_Category_1'].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 11,  7, 16, 15, 18, 10, 14, 13, 17,
#         9], dtype=int64)

# %%
df3=df[df['Product_Category_1']==18]
df3[df3['Gender']=='M']
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 304     1000053  P00117542      M  26-35           0             B
# 796     1000148  P00119242      M  51-55          17             B
# 1559    1000251  P00117542      M    55+          17             A
# 2167    1000338  P00117542      M  36-45           7             A
# 2515    1000406  P00117542      M  26-35          20             A
# ...         ...        ...    ...    ...         ...           ...
# 536467  1004560  P00054042      M  26-35           0             C
# 536562  1004577  P00327642      M  36-45           7             C
# 536944  1004644  P00327642      M  51-55           1             C
# 537097  1004661  P00269042      M  46-50          15             B
# 537361  1004708  P00344142      M  26-35           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 304                             1               0                  18
# ...

# %%
df1[df1['Age']=='26-35']
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 9       1000005  P00274942      M  26-35          20             A
# 10      1000005  P00251242      M  26-35          20             A
# 11      1000005  P00014542      M  26-35          20             A
# 12      1000005  P00031342      M  26-35          20             A
# 13      1000005  P00145042      M  26-35          20             A
# ...         ...        ...    ...    ...         ...           ...
# 537540  1004732  P00124642      M  26-35          14             B
# 537541  1004732  P00051442      M  26-35          14             B
# 537542  1004732  P00085242      M  26-35          14             B
# 537543  1004732  P00117242      M  26-35          14             B
# 537544  1004732  P00093342      M  26-35          14             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 9                               1               1                   8
# ...

# %%
df1.groupby('Occupation').count()['City_Category']
# Out:
# Occupation
# 0     28456
# 1     21906
# 2     11939
# 3      7164
# 4     19139
# 5      4512
# 6      8839
# 7     25113
# 8       852
# 9      3152
# 10      731
# 11     4341
# 12    14215
# 13     3995
# 14    10940
# 15     5329
# 16    11748
# 17    16847
# 18     2976
# 19     1499
# 20    16067
# Name: City_Category, dtype: int64

# %%
df3=df[df['Gender']=='M']
df4=df[df['Gender']=='F']

# %%
df4
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 14      1000006  P00231342      F  51-55           9             A
# ...         ...        ...    ...    ...         ...           ...
# 537472  1004726  P00037142      F  36-45          16             C
# 537473  1004726  P00058442      F  36-45          16             C
# 537474  1004726  P00303242      F  36-45          16             C
# 537475  1004727  P00295942      F    55+           0             C
# 537476  1004727  P00351142      F    55+           0             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df3.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  4.053800e+05  405380.000000   405380.000000       405380.000000
# mean   1.002961e+06       8.519705        0.405883            5.197748
# std    1.693252e+03       6.554518        0.491063            3.830816
# min    1.000002e+06       0.000000        0.000000            1.000000
# 25%    1.001492e+06       3.000000        0.000000            1.000000
# 50%    1.003007e+06       7.000000        0.000000            5.000000
# 75%    1.004352e+06      15.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           18.000000
#
#             Purchase
# count  405380.000000
# mean     9504.771713
# std      5051.057256
# min       185.000000
# 25%      5901.000000
# 50%      8112.000000
# 75%     12542.000000
# max     23961.000000

# %%
df4.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  1.321970e+05  132197.000000   132197.000000       132197.000000
# mean   1.003088e+06       6.742672        0.417733            5.595445
# std    1.774236e+03       6.242116        0.493188            3.476495
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       1.000000        0.000000            3.000000
# 50%    1.003093e+06       4.000000        0.000000            5.000000
# 75%    1.004651e+06      11.000000        1.000000            8.000000
# max    1.006039e+06      20.000000        1.000000           18.000000
#
#             Purchase
# count  132197.000000
# mean     8809.761349
# std      4721.440055
# min       185.000000
# 25%      5459.000000
# 50%      7929.000000
# 75%     11436.000000
# max     23959.000000

# %%
(df3['Purchase'].sum()/df['Purchase'].sum())*100
# Out:
# 76.78953782385656

# %%
(df4['Purchase'].sum()/df['Purchase'].sum())*100
# Out:
# 23.21046217614344

# %%
import matplotlib.pyplot as plt
df.groupby('City_Category').size().plot(kind='pie',autopct='%.1f%%')
plt.show()

# %%
df.groupby('Product_Category_1').size().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby("City_Category").sum()['Purchase']
# Out:
# C:\Users\balaj\AppData\Local\Temp\ipykernel_17424\765748399.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("City_Category").sum()['Purchase']
# City_Category
# A    1295668797
# B    2083431612
# C    1638567969
# Name: Purchase, dtype: int64

# %%
print(df.groupby('Occupation').sum()['Purchase'])
print(df.groupby('Occupation').sum()['Purchase'].plot(kind='bar'))
# Out:
# C:\Users\balaj\AppData\Local\Temp\ipykernel_17424\645434488.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   print(df.groupby('Occupation').sum()['Purchase'])
# C:\Users\balaj\AppData\Local\Temp\ipykernel_17424\645434488.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   print(df.groupby('Occupation').sum()['Purchase'].plot(kind='bar'))
# Occupation
# 0     625814811
# 1     414552829
# 2     233275393
# 3     160428450
# 4     657530393
# 5     112525355
# 6     185065697
# 7     549282744
# 8      14594599
# 9      53619309
# 10    114273954
# 11    105437359
# 12    300672105
# 13     71135744
# ...

# %% [markdown]
# ##### Here the Occupation 4 have purchased more than any other occupation

# %%
df4.groupby('Product_Category_1').size().plot(kind="bar")
# Out:
# <Axes: xlabel='Product_Category_1'>

# %% [markdown]
# #### Female Purchase more product category 5

# %%
df3.groupby('Product_Category_1').size().plot(kind="bar")
# Out:
# <Axes: xlabel='Product_Category_1'>

# %% [markdown]
# #### Male purchase product Category 1 in large quantity

# %%
print(df1.groupby('Product_Category_1').size())
print(df1.groupby('Product_Category_1').size().plot(kind='barh'))
# Out:
# Product_Category_1
# 1     55123
# 2      9553
# 3      7691
# 4      4495
# 5     60181
# 6      8178
# 7      1664
# 8     47648
# 9       162
# 10     2298
# 11     9481
# 12     1876
# 13     2333
# 14      665
# 15     2626
# 16     4057
# 17      276
# 18     1453
# dtype: int64
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# #### Here Married people buy product category 5 more than other

# %%
print(df2.groupby('Product_Category_1').size())
print(df2.groupby('Product_Category_1').size().plot(kind='barh'))
# Out:
# Product_Category_1
# 1     83230
# 2     13946
# 3     12158
# 4      7072
# 5     88411
# 6     11986
# 7      2004
# 8     64484
# 9       242
# 10     2734
# 11    14479
# 12     1999
# 13     3107
# 14      835
# 15     3577
# 16     5640
# 17      291
# 18     1622
# dtype: int64
# Axes(0.125,0.11;0.775x0.77)

# %%
df6=df1[df1['Gender']=='M']
df6.groupby('Product_Category_1').size().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %% [markdown]
# #### Married Male purchase product category 1 more than any other

# %%
df7=df1[df1['Gender']=='F']
df7.groupby('Product_Category_1').size().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %% [markdown]
# #### Married Women Purchase product category 5 more than any other

# %%
df8=df2[df2['Gender']=='F']
df8.groupby('Product_Category_1').size().plot(kind='bar')
print(df8['Purchase'].mean())
# Out:
# 8753.8092992439

# %% [markdown]
# #### Unmarried Women Purchase product Category 5 more than any other products

# %%
df9=df2[df2['Gender']=='M']
df9.groupby('Product_Category_1').size().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %% [markdown]
# #### Unmarried Male Purchase more product category 1 than any other products

# %%
df1.groupby('Age').size()
# Out:
# Age
# 18-25    20641
# 26-35    84166
# 36-45    42507
# 46-50    32194
# 51-55    26979
# 55+      13273
# dtype: int64

# %%
df2.groupby('Age').size()
# Out:
# Age
# 0-17      14707
# 18-25     76993
# 26-35    130524
# 36-45     64992
# 46-50     12332
# 51-55     10639
# 55+        7630
# dtype: int64

# %% [markdown]
# ## Which Occupation buy which product more

# %%
df.groupby("Product_ID").sum()['Purchase'].nlargest(10).sort_values().plot(kind='bar')
# Out:
# C:\Users\balaj\AppData\Local\Temp\ipykernel_17424\4073756865.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Product_ID").sum()['Purchase'].nlargest(10).sort_values().plot(kind='bar')
# <Axes: xlabel='Product_ID'>

# %%
import seaborn as sns
sns.countplot(x=df['Age'],hue=df['City_Category'])
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
l=[]
for i in range(len(df)):
    l.append(df['Gender'][i]+'_'+str(df['Marital_Status'][i]))

# %%
df['Marital_Gender']=l

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
sns.countplot(x=df['Age'],hue=df['Marital_Gender'])
# Out:
# <Axes: xlabel='Age', ylabel='count'>
